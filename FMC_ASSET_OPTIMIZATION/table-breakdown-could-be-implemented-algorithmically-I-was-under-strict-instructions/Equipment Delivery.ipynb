# %%
# %run '00_database_connectivity_setup.ipynb'
# Out:
#           x         y
# 0  0.381851  0.000599
# 1  0.155280  0.399155
# 2  0.436562  0.442039
# 3  0.742300  0.745614
# 4  0.561765  0.829729
# 5  0.416113  0.713841

# %%
# %%execsql
# DROP TABLE IF EXISTS  felipe.bic_azeqdeliv00_sum

# %%
# %%showsql
# select madlib.summary('sap_bi.bic_azeqdeliv00_int', 'felipe.bic_azeqdeliv00_sum');
# Out:
#                                          summary
# 0  (felipe.bic_azeqdeliv00_sum,29,155.058628082)

# %%
# %%showsql
# select target_column, distinct_values, missing_values, blank_values, min, max, most_frequent_values
# from felipe.bic_azeqdeliv00_sum
# where fraction_blank < 0.999 and distinct_values > 1;
# Out:
#     target_column  distinct_values  missing_values  blank_values   min   max  \
# 0   deliv_numb     343522           0               0             10.0  10.0
# 1   deliv_item     6023             0               0             6.0   6.0
# 2   equipment      1400377          0               14            0.0   18.0
# 3   recordmode     2                0               253           0.0   1.0
# 4   ucserialnr     1223066          0               99            0.0   18.0
# 5   material       60727            0               0             3.0   18.0
# 6   createdon      5105             0               0             8.0   8.0
# 7   crea_time      78540            0               0             6.0   6.0
# 8   bic_zvorgang   6                0               623           0.0   4.0
# 9   doc_categ      3                0               2211          0.0   1.0
# 10  customer       5469             0               54476         0.0   10.0
# ...

# %%
# %%showsql
# select deliv_numb, deliv_item, equipment, material, to_date(createdon, 'YYYYMMDD') as createdon, bic_zvorgang, customer, movetype,
# item_categ, plant, bic_zequihist, bic_zehistty
# from sap_bi.bic_azeqdeliv00_int limit 10;
# Out:
#    deliv_numb deliv_item           equipment     material   createdon  \
# 0  0080165411  000010     000000000010520075  SP-69-23610  2006-10-10
# 1  0080165411  000010     000000000010520076  SP-69-23610  2006-10-10
# 2  0080165411  000010     000000000010520077  SP-69-23610  2006-10-10
# 3  0080165411  000010     000000000010520078  SP-69-23610  2006-10-10
# 4  0080165411  000010     000000000010520079  SP-69-23610  2006-10-10
# 5  0080165411  000010     000000000010520080  SP-69-23610  2006-10-10
# 6  0080165411  000010     000000000010520081  SP-69-23610  2006-10-10
# 7  0080165411  000010     000000000010520082  SP-69-23610  2006-10-10
# 8  0080165411  000010     000000000010520083  SP-69-23610  2006-10-10
# 9  0080165411  000010     000000000010520084  SP-69-23610  2006-10-10
#
#   bic_zvorgang    customer movetype item_categ plant bic_zequihist  \
# 0  SDLS         0000451957  541      LBN        GSEA  0080165411
# ...
