# %%
# %run '00_database_connectivity_setup.ipynb'
# Out:
# C:\Anaconda2\lib\site-packages\pandas\computation\__init__.py:19: UserWarning: The installed version of numexpr 2.4.4 is not supported in pandas and will be not be used
#
#   UserWarning)

# %%
# %%hshowsql
# select * from SAPSR3."/BIC/AZPP_S0900"

# %%
# %%execsql
# DROP TABLE IF EXISTS  nate.bic_azcs_o0500_sum

# %%
# %%showsql
# select madlib.summary('sap_bi.bic_azcs_o0500_int', 'nate.bic_azcs_o0500_sum');
# Out:
#                                       summary
# 0  (nate.bic_azcs_o0500_sum,86,196.534942865)

# %%
# %%showsql
# select target_column, distinct_values, missing_values, blank_values, min, max, most_frequent_values
# from nate.bic_azcs_o0500_sum
# where fraction_blank < 0.999 and distinct_values > 1;
# Out:
#     target_column  distinct_values  missing_values  blank_values  min   max  \
# 0   notificatn     503477           0               1             0.0  12.0
# 1   ausbs          3736             0               0             8.0  8.0
# 2   ausvn          5324             0               0             8.0  8.0
# 3   auztb          566              0               0             6.0  6.0
# 4   auztv          66223            0               0             6.0  6.0
# 5   bic_zbautl_hd  815              0               500750        0.0  18.0
# 6   unit_day       2                0               41471         0.0  2.0
# 7   equipment      91399            0               111889        0.0  18.0
# 8   notif_orgn     4                0               41471         0.0  2.0
# 9   customer       1273             0               182091        0.0  10.0
# 10  down_indic     2                0               501193        0.0  1.0
# ...

# %%
# %%execsql
#
# CREATE OR REPLACE FUNCTION nate.my_to_date(text, text) RETURNS date AS $$
#
# BEGIN
#     IF to_number($1,'99999999') = 0 THEN
#         RETURN null;
#     ELSE
#         RETURN to_date($1, $2);
#     END IF;
# END;
#
# $$ LANGUAGE plpgsql

# %%
# %%showsql
# select notificatn, my_to_date(ausbs,'YYYYMMDD') as ausbs, my_to_date(ausvn,'YYYYMMDD') as ausvn, bic_zbautl_hd, equipment,
# notif_orgn, customer, down_indic, not_type, my_to_date(bic_zqmdat,'YYYYMMDD') as bic_zqmdat, division, funct_loc, salesorg, abckey,
# my_to_date(ch_on,'YYYYMMDD') as ch_on, changedby, bic_zaezeit, workcenter, bic_zawerk, plantsectn, bic_zbequi, bic_zsupfloc,
# comp_code, my_to_date(calday,'YYYYMMDD') as calday, createdby, bic_zcrtdat, bic_zmwcntr, bus_area, plgrp, plant, co_area,
# costcenter, my_to_date(bic_zltrmn,'YYYYMMDD') as bic_zltrmn, material, maintplant, maintroom, bic_zmzeit, objnr,
# my_to_date(bic_zntfcompl,'YYYYMMDD') as bic_zntfcompl, nfcat_grp, pp_locat, my_to_date(bic_zstrmn,'YYYYMMDD') as bic_zstrmn,
# bic_zswerk, sales_off, sales_grp, bic_zcslngtxt, bic_zcounter, bic_zempl_coo, bic_zqwrnum
# from sap_bi.bic_azcs_o0500_int limit 5
# Out:
#      notificatn ausbs ausvn bic_zbautl_hd           equipment notif_orgn  \
# 0  000300462652  None  None                000000000010778492  06
# 1  000300463208  None  None                000000000011969337  06
# 2  000300463876  None  None                000000000010028049  06
# 3  000300464951  None  None                000000000011637468  06
# 4  000300465150  None  None                000000000010859715  06
#
#   customer down_indic not_type  bic_zqmdat division funct_loc salesorg abckey  \
# 0                      S3       2015-01-24
# 1                      S3       2015-01-28
# 2                      S3       2015-02-02
# 3                      S3       2015-02-08
# 4                      S3       2015-02-09
#
#   ch_on changedby bic_zaezeit workcenter bic_zawerk plantsectn bic_zbequi  \
# 0  None            000000      00000000
# 1  None            000000      00000000
# 2  None            000000      00000000
# 3  None            000000      00000000
# ...
