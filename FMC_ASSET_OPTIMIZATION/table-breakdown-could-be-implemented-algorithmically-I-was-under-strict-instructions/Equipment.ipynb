# %%
# %run '00_database_connectivity_setup.ipynb'

# %%
# %%execsql
# DROP TABLE IF EXISTS  nate.bic_azequip00_int

# %%
# %%showsql
# select madlib.summary('sap_bi.bic_azequip00_int', 'nate.bic_azequip00_sum');
# Out:
#                                     summary
# 0  (nate.bic_azequip00_sum,24,163.71477294)

# %%
# %%showsql
# select target_column, distinct_values, missing_values, blank_values, min, max, most_frequent_values
# from nate.bic_azequip00_sum
# where fraction_blank < 0.999 and distinct_values > 1;
# Out:
#     target_column  distinct_values  missing_values  blank_values  min   max  \
# 0   equipment      4498389          0               0             4.0  18.0
# 1   dateto         4889             0               0             8.0  8.0
# 2   recordmode     2                0               5724906       0.0  1.0
# 3   datefrom       6112             0               0             8.0  8.0
# 4   equitype       226              0               5642861       0.0  10.0
# 5   funct_loc      41120            0               5097588       0.0  30.0
# 6   maintplant     80               0               4590631       0.0  4.0
# 7   material       133888           0               88133         0.0  18.0
# 8   equi_cat       8                0               69548         0.0  1.0
# 9   bic_zsupeqip   51204            0               4949499       0.0  18.0
# 10  ucserialnr     4047594          0               177157        0.0  18.0
# 11  invent_no      13960            0               5465537       0.0  25.0
# 12  bic_zsyssts    70               0               0             4.0  19.0
# 13  bic_zflc_loc1  1113             0               5097588       0.0  27.0
# 14  bic_zflc_loc2  13998            0               5116315       0.0  21.0
# 15  bic_zflc_loc3  3877             0               5242747       0.0  27.0
# 16  bic_zflc_loc4  21239            0               5276736       0.0  28.0
# 17  bic_zflc_loc5  743              0               5476673       0.0  30.0
# 18  bic_zflc_loc6  1436             0               5502334       0.0  30.0
# 19  bic_zdayoper   5753             0               0             5.0  8.0
# 20  bic_zequihist  41120            0               5186614       0.0  30.0
# 21  bic_zehistty   3                0               5097588       0.0  12.0
# 22  crea_time      72217            0               0             6.0  6.0
# 23  createdby      2866             0               70532         0.0  12.0
#
#                                                                                                                                                                                         most_frequent_values
# 0   [000000000011352160, 000000000013197064, 000000000011492342, 000000000010084042, 000000000013196786, 000000000014416844, 000000000010088523, 000000000014412529, 000000000014416810, 000000000014418382]
# 1   [99991231, 99991231, 99991231, 99991231, 99991231, 99991231, 20160127, 20160127, 20151109, 20151109]
# 2   [, , , , , , N, N]
# 3   [20120927, 20120811, 20121115, 20130203, 20150619, 20140227, 20091217, 20120918, 20110922, 20110607]
# 4   [, , , , , , GV7IN10KMV, SST-001, SST-001, SST-001]
# 5   [, , , , , , 7350-00331-1-00001, 7350-00331-1-00001, 7350-00331-1-00001, 7350-00331-1-00001]
# 6   [, , , , , , KOS2, KOS2, KOS2, KOS2]
# 7   [, NON FMC PART, P505327, P505327, P505327, P505327, 000000000100021358, 000000000007104366, P516108, P516108]
# 8   [S, S, S, S, S, S, M, M, M, M]
# 9   [, , , , , , 000000000010071539, 000000000010071539, 000000000010004875, 000000000010051276]
# 10  [, , , , , , 000000000000000001, 000000000000000001, 000000000000000001, 000000000000000001]
# 11  [, , , , , , EPPERSON, HOUSTON RENTAL, GV M130 4-1/16" 10K M, PIC]
# 12  [AVLB, AVLB, AVLB, AVLB, AVLB, AVLB, ASEQ, ASEQ, ASEQ, ASEQ]
# 13  [, , , , , , C, C, C, C]
# 14  [, , , , , , C-CD, C-CD, C-CD, C-CD]
# 15  [, , , , , , C-CD-STAD, C-CD-STAD, C-CD-STAD, C-CD-STAD]
# 16  [, , , , , , C-CA-TEPA-PZF01, C-CA-TEPA-PZF01, C-CA-TEPA-PZF01, C-CD-STAD-ST010]
# 17  [, , , , , , N, N, N, C-CD-COPN-EK001]
# 18  [, , , , , , C-CA-TOTL, C-CA-TOTL, C-CA-TOTL, C-CA-TOTL]
# 19  [0.000, 1.000, 1.000, 1.000, 1.000, 1.000, 3.000, 1219.000, 2.000, 224.000]
# 20  [, , , , , , 7350-00331-1-00001, 7350-00331-1-00001, 7350-00331-1-00001, 7350-00331-1-00001]
# 21  [, , , , , , INSTALLATION, INSTALLATION, INSTALLATION, INSTALLATION]
# 22  [000000, 000000, 000000, 000000, 000000, 000000, 000100, 000100, 000100, 000100]
# 23  [BACKGROUNDUS, BACKGROUNDUS, BACKGROUNDUS, BACKGROUNDUS, GUNDERJ, GUNDERJ, GUNDERJ, GUNDERJ, GUNDERJ, KOSHAN]

# %%
# %%execsql
#
# CREATE OR REPLACE FUNCTION my_to_date(text, text) RETURNS date AS $$
#
# BEGIN
#     IF to_number($1,'99999999') = 0 THEN
#         RETURN null;
#     ELSE
#         RETURN to_date($1, $2);
#     END IF;
# END;
#
# $$ LANGUAGE plpgsql

# %%
# %%showsql
# select *
# from sap_bi.bic_azequip00_int limit 5
# Out:
#             equipment    dateto recordmode  datefrom equitype  \
# 0  000000000011355361  99991231             20121213
# 1  000000000011355362  99991231             20121213
# 2  000000000011355363  99991231             20090602
# 3  000000000011355364  99991231             20090602
# 4  000000000011355365  99991231             20090602
#
#                  funct_loc maintplant      material equi_cat  \
# 0  C-CA-TEPA-PZF01-PR608-A  FKIA       P211596       S
# 1  C-CA-TEPA-PZF01-PR608-A  FKIA       P211596       S
# 2                                      P155690       S
# 3                                      P166530       S
# 4                                      P205161-0033  S
#
#          bic_zsupeqip      ucserialnr invent_no bic_zsyssts bic_zflc_loc1  \
# 0  000000000011679470  100839-88311-3            ASEQ        C
# 1  000000000011679470  100839-88311-4            ASEQ        C
# 2                      14451-7                   AVLB
# 3                      14382-7                   AVLB
# 4                      14416-6                   AVLB
#
#   bic_zflc_loc2 bic_zflc_loc3    bic_zflc_loc4            bic_zflc_loc5  \
# 0  C-CA          C-CA-TEPA     C-CA-TEPA-PZF01  C-CA-TEPA-PZF01-PR608-A
# 1  C-CA          C-CA-TEPA     C-CA-TEPA-PZF01  C-CA-TEPA-PZF01-PR608-A
# 2
# 3
# 4
#
#   bic_zflc_loc6 bic_zdayoper            bic_zequihist  bic_zehistty crea_time  \
# 0  C-CA-TOTL     1142.000     C-CA-TEPA-PZF01-PR608-A  INSTALLATION  152038
# 1  C-CA-TOTL     1142.000     C-CA-TEPA-PZF01-PR608-A  INSTALLATION  152038
# 2                2432.000                                            000000
# 3                2432.000                                            000000
# 4                2432.000                                            000000
#
#   createdby
# 0  WILLIAD1
# 1  WILLIAD1
# 2  QUINONR
# 3  QUINONR
# 4  QUINONR
