# %%
# %run '00_database_connectivity_setup.ipynb'
# Out:
#           x         y
# 0  0.415490  0.285182
# 1  0.417673  0.267417
# 2  0.949156  0.801813
# 3  0.556610  0.823992
# 4  0.874103  0.368105
# 5  0.462129  0.555474

# %%
# %%execsql
# DROP TABLE IF EXISTS  felipe.bic_mfunct_loc_sum

# %%
# %%showsql
# select madlib.summary('sap_bi.bic_mfunct_loc_int', 'felipe.bic_mfunct_loc_sum');
# Out:
#                                         summary
# 0  (felipe.bic_mfunct_loc_sum,52,26.2206759453)

# %%
# %%showsql
# select target_column, distinct_values, missing_values, blank_values, min, max, most_frequent_values
# from felipe.bic_mfunct_loc_sum
# where fraction_blank < 0.999 and distinct_values > 1;
# Out:
#     target_column  distinct_values  missing_values  blank_values  min   max  \
# 0   funct_loc      49030            0               1             0.0  30.0
# 1   comp_code      13               0               2474          0.0  4.0
# 2   costcenter     5                0               48837         0.0  10.0
# 3   co_area        3                0               2474          0.0  4.0
# 4   day_start      896              0               0             8.0  8.0
# 5   fl_type        3                0               1             0.0  1.0
# 6   maintloc       5                0               48351         0.0  6.0
# 7   maintplant     45               0               3305          0.0  4.0
# 8   maintroom      570              0               48209         0.0  8.0
# 9   planplant      44               0               2324          0.0  4.0
# 10  pmplangrp      5                0               48831         0.0  3.0
# ...

# %%
# %%execsql
#
# CREATE OR REPLACE FUNCTION my_to_date(text, text) RETURNS date AS $$
#
# BEGIN
#     IF to_number($1,'99999999') = 0 THEN
#         RETURN null;
#     ELSE
#         RETURN to_date($1, $2);
#     END IF;
# END;
#
# $$ LANGUAGE plpgsql

# %%
# %%showsql
# select funct_loc, comp_code, costcenter, my_to_date(day_start, 'YYYYMMDD') as day_start, maintloc, maintplant, maintroom, planplant,
# workcenter, bic_zflstrind, bic_zsupfloc, bic_zflc_loc1, bic_zflc_loc2, bic_zflc_loc3, bic_zflc_loc4, bic_zflc_loc5, bic_zflc_loc6,
# my_to_date(bic_zfldpdt, 'YYYYMMDD') as bic_zfldpdt, bic_znumopw, bic_zlatit,bic_zlongit
# from sap_bi.bic_mfunct_loc_int limit 10;
# Out:
#          funct_loc comp_code costcenter   day_start maintloc maintplant  \
# 0  1-RJS-049-RJS    EWBO                 1984-06-01           4026
# 1  1-RJS-305-RJS    EWBO                 1989-09-01           4026
# 2  1-RJS-422-RJS    EWBO                 1999-03-19           4026
# 3  1-RJS-491-RJS    EWBO                 1997-03-21           4026
# 4  1-RJS-499-RJS    EWBO                 2000-01-16           4026
# 5  1234                                  None
# 6  3-BR-002-RJS     EWBO                 1998-06-09           4026
# 7  3-ESS-110HP-ESS  EWBO                 2002-08-26           4026
# 8  3-LI-001-RJS     EWBO                 1983-11-01           4026
# 9  3-LI-005-RJS     EWBO                 1984-07-01           4026
#
#   maintroom planplant workcenter bic_zflstrind  bic_zsupfloc    bic_zflc_loc1  \
# 0            4026                 Z8            BC-LINGUADO   1-RJS-049-RJS
# 1            4026                 Z8            BC-ALBACORA   1-RJS-305-RJS
# ...
