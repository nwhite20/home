# %%
# %run '00_database_connectivity_setup.ipynb'
# Out:
#           x         y
# 0  0.489855  0.573534
# 1  0.490041  0.320402
# 2  0.836111  0.481961
# 3  0.492016  0.305475
# 4  0.844573  0.987999
# 5  0.763850  0.494735

# %%
# %%execsql
# DROP TABLE IF EXISTS  felipe.bic_azqn_o30400_sum

# %%
# %%showsql
# select madlib.summary('sap_bi.bic_azqn_o30400_int', 'felipe.bic_azqn_o30400_sum');
# Out:
#                                          summary
# 0  (felipe.bic_azqn_o30400_sum,55,174.315740108)

# %%
# %%showsql
# select target_column, distinct_values, missing_values, blank_values, min, max, most_frequent_values
# from felipe.bic_azqn_o30400_sum
# where fraction_blank < 0.999 and distinct_values > 1;
# Out:
#     target_column  distinct_values  missing_values  blank_values   min   max  \
# 0   notificatn     412967           0               0             12.0  12.0
# 1   nfcat_code     81               0               1480          0.0   4.0
# 2   nfcat_type     2                0               1480          0.0   1.0
# 3   nfcat_grp      223              0               1480          0.0   8.0
# 4   purch_org      34               0               224295        0.0   4.0
# 5   vendor         3713             0               207973        0.0   10.0
# 6   salesorg       29               0               439283        0.0   4.0
# 7   distr_chan     3                0               439323        0.0   2.0
# 8   division       9                0               439323        0.0   2.0
# 9   customer       951              0               434264        0.0   10.0
# 10  funct_loc      296              0               444465        0.0   30.0
# ...

# %%
# %%execsql
#
# CREATE OR REPLACE FUNCTION my_to_date(text, text) RETURNS date AS $$
#
# BEGIN
#     IF to_number($1,'99999999') = 0 THEN
#         RETURN null;
#     ELSE
#         RETURN to_date($1, $2);
#     END IF;
# END;
#
# $$ LANGUAGE plpgsql

# %%
# %%showsql
# select notificatn, nfcat_code, nfcat_grp, purch_org, vendor, salesorg, division, customer, funct_loc, equipment, material, plant,
# my_to_date(bic_cqncpldat, 'YYYYMMDD') as bic_cqncpldat, oi_ebeln, oi_ebelp, not_type, base_uom, rstt_ftime, tctlstchg,
# bic_zprodord, mat_doc, mat_item, my_to_date(ausvn, 'YYYYMMDD') as ausvn, my_to_date(ausbs, 'YYYYMMDD') as ausbs,
# pur_group, auztv, auztb, bic_zrev_lvl, project, my_to_date(bic_zdt_osno, 'YYYYMMDD') as bic_zdt_osno, project,
# my_to_date(bic_zdt_nopr, 'YYYYMMDD') as bic_zdt_nopr, bic_ztm_osno, bic_ztm_nopr
# from sap_bi.bic_azqn_o30400_int limit 10;
# Out:
#      notificatn nfcat_code nfcat_grp purch_org      vendor salesorg division  \
# 0  000200434342  0020       QI000015
# 1  000200481612  0010       QE000015            0000003023
# 2  000200434645  0050       QI000015
# 3  000200435140  0040       QI000015
# 4  000200435411  0040       QI000015
# 5  000200435872  0020       QI000015
# 6  000200435884  0070       QI000015
# 7  000200437110  0090       QI000015
# 8  000200437459  0040       QI000015
# 9  000200437721  0090       QI000015
#
#   customer funct_loc equipment            material plant bic_cqncpldat  \
# 0                               000000000573453002  1201  None
# 1                               P6000127558         KOS1  None
# 2                               P1000108406         EWHG  None
# 3                               000000000000251183  1201  None
# 4                               LA100-RK            1201  None
# 5                               15083 F             1201  None
# ...
