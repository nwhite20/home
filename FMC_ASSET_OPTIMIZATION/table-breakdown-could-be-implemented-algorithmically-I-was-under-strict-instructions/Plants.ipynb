# %%
# %run '00_database_connectivity_setup.ipynb'
# Out:
# C:\Anaconda2\lib\site-packages\pandas\computation\__init__.py:19: UserWarning: The installed version of numexpr 2.4.4 is not supported in pandas and will be not be used
#
#   UserWarning)

# %%
# %%showsql
# select * from sap_bi.bi0_pplant_int order by random() limit 10
# Out:
#   plant objvers changed altitude bpartner country county_cde distr_chan  \
# 0  5137  A               0.000             US                 01
# 1  1112  A               0.000             US                 01
# 2  EMPN  A               0.000             NO                 01
# 3  5145  A               0.000             US                 01
# 4  4024  A               0.000             BR                 01
# 5  INDL  A               0.000             IN                 01
# 6  SJNV  A               0.000             CA                 01
# 7  ESST  A               0.000             TN                 01
# 8  5138  A               0.000             US                 01
# 9  EWDF  A               0.000             NG                 01
#
#   factcal_id gn_par_ssy latitude loc_currcy logsys longitude plantcat  \
# 0  ZB                    0E-12    USD               0E-12
# 1  ZB                    0E-12    USD               0E-12
# ...

# %%
# %%execsql
# DROP TABLE IF EXISTS  nate.bi0_pplant_sum

# %%
# %%showsql
# select madlib.summary('sap_bi.bi0_pplant_int', 'nate.bi0_pplant_sum');
# Out:
#                                   summary
# 0  (nate.bi0_pplant_sum,43,2.64686512947)

# %%
# %%showsql
# select target_column, distinct_values, missing_values, blank_values, min, max, most_frequent_values
# from nate.bi0_apur_o0100_sum
# where fraction_blank < 0.999 and distinct_values > 1;
# Out:
#     target_column  distinct_values  missing_values  blank_values   min   max  \
# 0   oi_ebeln       1953801          0               0             1.0   10.0
# 1   oi_ebelp       5175             0               0             5.0   5.0
# 2   compl_del      2                0               1124470       0.0   1.0
# 3   createdon      4415             0               0             8.0   8.0
# 4   pstng_date     4010             0               0             8.0   8.0
# 5   material       326296           0               2419466       0.0   18.0
# 6   matl_group     1177             0               737722        0.0   9.0
# 7   plant          182              0               691369        0.0   4.0
# 8   purch_org      52               0               691351        0.0   4.0
# 9   pur_group      912              0               691351        0.0   3.0
# 10  stor_loc       1046             0               2037105       0.0   4.0
# ...

# %% [markdown]
# The query below includes the columns that have good data. (NOTE - this was selected out of columns with less than 200 blank values, rather than out of the query above which selects all that have less then 0.999 blank)

# %%
# %%showsql
# select plant, country,loc_currcy, postal_cd, purch_org, region, rt_custpl, salesorg, comp_code, bic_zlocation, bic_zregion, bic_zdivision,
# bic_zdivisin2, dbbusname from sap_bi.bi0_pplant_int limit 5;
# Out:
#   plant country loc_currcy postal_cd purch_org region rt_custpl salesorg  \
# 0  MCHI  US                 60601               IL
# 1  CDD
# 2  GENR  US                 60601
# 3  EDDS  US      USD        92833     EDDS      CA               EDDS
# 4  EFSS  US                 77032     EFSS      TX
#
#   comp_code bic_zlocation bic_zregion bic_zdivision bic_zdivisin2 dbbusname
# 0  MCHI
# 1
# 2  MCHI
# 3  EDDS                                                            SUBSEA
# 4  EFSS                                                            SUBSEA
