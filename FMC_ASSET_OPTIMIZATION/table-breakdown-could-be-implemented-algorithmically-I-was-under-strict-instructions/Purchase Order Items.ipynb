# %%
# %run '00_database_connectivity_setup.ipynb'

# %%
# %%execsql
# DROP TABLE IF EXISTS  nate.bi0_apur_o0100_sum

# %%
# %%showsql
# select madlib.summary('sap_bi.bi0_apur_o0100_int', 'nate.bi0_apur_o0100_sum');
# Out:
#                                        summary
# 0  (nate.bi0_apur_o0100_sum,118,891.595417976)

# %%
# %%showsql
# select target_column, distinct_values, fraction_blank, min, max, most_frequent_values
# from nate.bi0_apur_o0100_sum
# where fraction_blank < 0.999 and distinct_values > 1;
# Out:
#     target_column  distinct_values  fraction_blank   min   max  \
# 0   oi_ebeln       1953801          0.000000        1.0   10.0
# 1   oi_ebelp       5175             0.000000        5.0   5.0
# 2   compl_del      2                0.170892        0.0   1.0
# 3   createdon      4415             0.000000        8.0   8.0
# 4   pstng_date     4010             0.000000        8.0   8.0
# 5   material       326296           0.367700        0.0   18.0
# 6   matl_group     1177             0.112116        0.0   9.0
# 7   plant          182              0.105071        0.0   4.0
# 8   purch_org      52               0.105069        0.0   4.0
# 9   pur_group      912              0.105069        0.0   3.0
# 10  stor_loc       1046             0.309591        0.0   4.0
# 11  vendor         22300            0.312553        0.0   10.0
# 12  loc_currcy     11               0.105069        0.0   3.0
# 13  order_curr     40               0.105069        0.0   3.0
# ...
