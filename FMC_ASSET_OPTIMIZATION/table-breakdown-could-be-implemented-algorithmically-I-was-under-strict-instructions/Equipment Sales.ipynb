# %%
# %run '00_database_connectivity_setup.ipynb'
# Out:
# C:\Anaconda2\lib\site-packages\pandas\computation\__init__.py:19: UserWarning: The installed version of numexpr 2.4.4 is not supported in pandas and will be not be used
#
#   UserWarning)
#           x         y
# 0  0.224190  0.100459
# 1  0.728265  0.675058
# 2  0.490139  0.707608
# 3  0.679842  0.095076
# 4  0.329512  0.234735
# 5  0.613243  0.884075

# %%
# %%execsql
# DROP TABLE IF EXISTS  felipe.bic_azeqsales00_sum

# %%
# %%showsql
# select madlib.summary('sap_bi.bic_azeqsales00_int', 'felipe.bic_azeqsales00_sum');
# Out:
#                                          summary
# 0  (felipe.bic_azeqsales00_sum,29,19.2052800655)

# %%
# %%execsql
#
# CREATE OR REPLACE FUNCTION my_to_date(text, text) RETURNS date AS $$
#
# BEGIN
#     IF to_number($1,'99999999') = 0 THEN
#         RETURN null;
#     ELSE
#         RETURN to_date($1, $2);
#     END IF;
# END;
#
# $$ LANGUAGE plpgsql

# %%
# %%showsql
# select target_column, distinct_values, missing_values, blank_values, min, max, most_frequent_values
# from felipe.bic_azeqsales00_sum
# where fraction_blank < 0.999 and distinct_values > 1;
# Out:
#     target_column  distinct_values  missing_values  blank_values  min   max  \
# 0   doc_number     14382            0               0             6.0  10.0
# 1   s_ord_item     1661             0               0             6.0  6.0
# 2   equipment      19477            0               1             0.0  18.0
# 3   ucserialnr     15984            0               0             1.0  18.0
# 4   material       4987             0               0             7.0  18.0
# 5   createdon      3009             0               0             8.0  8.0
# 6   customer       105              0               0             4.0  10.0
# 7   doc_type       2                0               0             3.0  3.0
# 8   item_categ     2                0               0             3.0  4.0
# 9   createdby      167              0               0             3.0  10.0
# 10  plant          9                0               0             4.0  4.0
# ...

# %%
# %%showsql
# select doc_number, s_ord_item, equipment, ucserialnr, material, my_to_date(createdon, 'YYYYMMDD') as createdon, customer,
# doc_type, item_categ, plant, bic_zequihist
# from sap_bi.bic_azeqsales00_int
# Out:
#        doc_number s_ord_item           equipment          ucserialnr  \
# 0      0000003506  000120     000000000010016928  000000000000000001
# 1      0000003533  000120     000000000010032467  000000000000000001
# 2      0000003590  000120     000000000010001945  000000000000000001
# 3      0000003710  000120     000000000010002882  000000000000000001
# 4      0000003820  000120     000000000010017315  000000000000000001
# 5      0000003842  000120     000000000010017441  000000000000000001
# 6      0000003852  000120     000000000010001406  000000000000000001
# 7      0000003861  000120     000000000010006643  540907/A2-01
# 8      0000003867  000120     000000000010033638  000000000000000001
# 9      0000003918  000120     000000000010000504  000000000000000001
# 10     0000003921  000120     000000000010017151  000000000000000001
# 11     0000003949  000120     000000000010000433  000000000000000001
# 12     0000003958  000120     000000000010043949  000000000000000001
# ...
