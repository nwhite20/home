# %%
# %run '00_database_connectivity_setup.ipynb'
# Out:
# C:\Anaconda2\lib\site-packages\pandas\computation\__init__.py:19: UserWarning: The installed version of numexpr 2.4.4 is not supported in pandas and will be not be used
#
#   UserWarning)

# %%
# %%showsql
# select * from sap_bi.bic_azcs_o0200_int order by random() limit 10
# Out:
#        cs_order bic_zopact recordmode opr_pldwrk workcenter coord_type  \
# 0  000001157959  0080       N          0.0        9929500    ZS03
# 1  000001049421  2100       N          1.0        1333-A3    ZS01
# 2  000001378301  0190       N          2.0        50102      ZS04
# 3  000001024693  0020       N          0.0        1333-E     ZS02
# 4  000001131220  4140       N          0.0        SERV-SCM   ZS03
# 5  000001149512  0030       N          2.5        5100       ZS04
# 6  000001414436  0010       N          0.0        8080       ZS03
# 7  000001156969  0080       N          0.0        ISSUE      ZS04
# 8  000001401010  0040       N          0.5        8160       ZS04
# 9  000001039412  0040       N          16.0       5060-1     ZS04
#
#             equipment    calday pmacttype pmplangrp opr_actwrk assembly  \
# 0  000000000010803414  20111118  030       200       0.0
# 1  000000000010000857  20090429  003       230       0.0
# ...

# %%
# %%execsql
# DROP TABLE IF EXISTS  nate.bic_azcs_o0200_sum

# %%
# %%showsql
# select madlib.summary('sap_bi.bic_azcs_o0200_int', 'nate.bic_azcs_o0200_sum');
# Out:
#                                        summary
# 0  (nate.bic_azcs_o0200_sum,144,364.507106066)

# %%
# %%showsql
# select target_column, distinct_values, missing_values, blank_values, min, max, most_frequent_values
# from nate.bic_azcs_o0200_sum
# where fraction_blank < 0.999 and distinct_values > 1;
# Out:
#      target_column  distinct_values  missing_values  blank_values   min   max  \
# 0   cs_order        528350           0               0             12.0  12.0
# 1   bic_zopact      4225             0               0             4.0   4.0
# 2   recordmode      2                0               53912         0.0   1.0
# 3   opr_pldwrk      1515             0               0             3.0   7.0
# 4   workcenter      1331             0               83317         0.0   8.0
# 5   coord_type      15               0               0             4.0   4.0
# 6   equipment       71053            0               539799        0.0   18.0
# 7   calday          5297             0               0             8.0   8.0
# 8   pmacttype       47               0               0             3.0   3.0
# 9   pmplangrp       41               0               0             3.0   3.0
# 10  opr_actwrk      35144            0               0             3.0   8.0
# ...

# %% [markdown]
# The query below includes the columns that have good data.

# %%
# %%showsql
# select * from sap_bi.bic_azcs_o0200_int limit 5; #TODO
# Out:
#        cs_order bic_zopact recordmode opr_pldwrk workcenter coord_type  \
# 0  000001272461  0040       N          0.0        WORKSHOP   ZS02
# 1  000001272461  0050       N          0.0        WORKSHOP   ZS02
# 2  000001272461  0060       N          0.0        WORKSHOP   ZS02
# 3  000001272461  0170       N          0.0        WORKSHOP   ZS02
# 4  000001272461  0190       N          0.0        WORKSHOP   ZS02
#
#             equipment    calday pmacttype pmplangrp opr_actwrk assembly  \
# 0  000000000013665969  20131015  004       200       0.0
# 1  000000000013665969  20131015  004       200       0.0
# 2  000000000013665969  20131015  004       200       0.0
# 3  000000000013665969  20131015  004       200       0.0
# 4  000000000013665969  20131015  004       200       0.0
#
#   planplant    customer storno division funct_loc salesorg distr_chan  \
# 0  EWBV      0000046990         01                 EWBV     01
# 1  EWBV      0000046990         01                 EWBV     01
# ...
