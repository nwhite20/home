# %%
# %run '00_database_connectivity_setup.ipynb'
# Out:
# C:\Anaconda2\lib\site-packages\pandas\computation\__init__.py:19: UserWarning: The installed version of numexpr 2.4.4 is not supported in pandas and will be not be used
#
#   UserWarning)

# %%
# %%execsql
# DROP TABLE IF EXISTS  felipe.bic_azdef_o0100_sum

# %%
# %%showsql
# select madlib.summary('sap_bi.bic_azdef_o0100_int', 'felipe.bic_azdef_o0100_sum');
# Out:
#                                          summary
# 0  (felipe.bic_azdef_o0100_sum,35,59.2569000721)

# %%
# %%execsql
#
# CREATE OR REPLACE FUNCTION my_to_date(text, text) RETURNS date AS $$
#
# BEGIN
#     IF to_number($1,'99999999') = 0 THEN
#         RETURN null;
#     ELSE
#         RETURN to_date($1, $2);
#     END IF;
# END;
#
# $$ LANGUAGE plpgsql

# %%
# %%showsql
# select target_column, distinct_values, missing_values, blank_values, min, max, most_frequent_values
# from felipe.bic_azdef_o0100_sum
# where fraction_blank < 0.999 and distinct_values > 1;
# Out:
#     target_column  distinct_values  missing_values  blank_values   min   max  \
# 0   bic_zissue_id  238              0               0             7.0   7.0
# 1   bic_zid        220084           0               0             10.0  10.0
# 2   bic_zmesloc    4                0               237           0.0   1.0
# 3   bic_zdefects   2                0               0             1.0   1.0
# 4   bic_zworder    23733            0               5089          0.0   13.0
# 5   bic_zoperno    688              0               178478        0.0   4.0
# 6   bic_zclosedby  832              0               23730         0.0   10.0
# 7   bic_zdtime     205925           0               237           0.0   19.0
# 8   bic_zdtimecld  220084           0               6369          0.0   19.0
# 9   bic_zenterby   924              0               237           0.0   10.0
# 10  bic_zidmaster  13735            0               0             6.0   6.0
# ...

# %%
# %%showsql
# select bic_zissue_id, bic_zid, bic_zworder, bic_zworder, bic_zclosedby, bic_zdtime, bic_zdtimecld, bic_zenterby, bic_zidmaster,
# bic_zissue, bic_zissuegrp, bic_zissuetyp, bic_zordstat, bic_zowner, bic_zrelated, bic_ztool, bic_ztoolreq
# from sap_bi.bic_azdef_o0100_int limit 10
# Out:
#      bic_zissue_id     bic_zid    bic_zworder    bic_zworder bic_zclosedby  \
# 0     0000000       0000489088  SSHFPHOL-0103  SSHFPHOL-0103
# 1     0000000       0000499718  SSHLLSTK-0222  SSHLLSTK-0222
# 2     0000000       0000496958  SSHBPSXP-0801  SSHBPSXP-0801
# 3     0000000       0000498449  SSHSHSTO-0501  SSHSHSTO-0501
# 4     0000000       0000501496  SSFTUFFD-0912  SSFTUFFD-0912
# 5     0000000       0000500280  SSHNOGFT-0101  SSHNOGFT-0101
# 6     0000000       0000500281  SSHNOGFT-0102  SSHNOGFT-0102
# 7     0000000       0000500744  SSHNOGFT-0910  SSHNOGFT-0910
# 8     0000000       0000497969  SSHBPSXP-0908  SSHBPSXP-0908
# 9     0000000       0000497970  SSHBPSXP-0913  SSHBPSXP-0913
# 10    0000000       0000499423  SSHLLSTK-0203  SSHLLSTK-0203
# 11    0000000       0000499424  SSHLLSTK-0219  SSHLLSTK-0219
# 12    0000000       0000499425  SSHLLSTK-0221  SSHLLSTK-0221
# 13    0000000       0000499426  SSHLLSTK-0223  SSHLLSTK-0223
# ...
