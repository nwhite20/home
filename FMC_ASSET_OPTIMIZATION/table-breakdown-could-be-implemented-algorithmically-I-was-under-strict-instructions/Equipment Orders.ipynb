# %%
# %run '00_database_connectivity_setup.ipynb'
# Out:
#           x         y
# 0  0.368987  0.231227
# 1  0.599593  0.733049
# 2  0.370381  0.814613
# 3  0.039988  0.046026
# 4  0.223477  0.985376
# 5  0.221647  0.663017

# %%
# %%execsql
# DROP TABLE IF EXISTS  felipe.bic_azeqpmord00_sum

# %%
# %%showsql
# select madlib.summary('sap_bi.bic_azeqpmord00_int', 'felipe.bic_azeqpmord00_sum');
# Out:
#                                          summary
# 0  (felipe.bic_azeqpmord00_sum,26,79.1331710815)

# %%
# %%execsql
#
# CREATE OR REPLACE FUNCTION my_to_date(text, text) RETURNS date AS $$
#
# BEGIN
#     IF to_number($1,'99999999') = 0 THEN
#         RETURN null;
#     ELSE
#         RETURN to_date($1, $2);
#     END IF;
# END;
#
# $$ LANGUAGE plpgsql

# %%
# %%showsql
# select target_column, distinct_values, missing_values, blank_values, min, max, most_frequent_values
# from felipe.bic_azeqpmord00_sum
# where fraction_blank < 0.999 and distinct_values > 1;
# Out:
#     target_column  distinct_values  missing_values  blank_values   min   max  \
# 0   coorder        336161           0               0             12.0  12.0
# 1   equipment      78967            0               0             18.0  18.0
# 2   recordmode     2                0               46402         0.0   1.0
# 3   notificatn     199883           0               204656        0.0   12.0
# 4   bic_zsortfld   3953             0               398822        0.0   20.0
# 5   bic_zbearb     2                0               402127        0.0   1.0
# 6   bic_zobjvw     2                0               67126         0.0   1.0
# 7   ucserialnr     64980            0               4775          0.0   18.0
# 8   material       20284            0               3334          0.0   18.0
# 9   createdon      5175             0               0             8.0   8.0
# 10  crea_time      69155            0               0             6.0   6.0
# ...

# %%
# %%showsql
# select coorder, equipment, notificatn, bic_zsortfld, material, my_to_date(createdon, 'YYYYMMDD') as createdon, coord_type,
# maintplant, priority, bic_zequihist
# from sap_bi.bic_azeqpmord00_int limit 10
# Out:
#         coorder           equipment notificatn bic_zsortfld     material  \
# 0  000001074742  000000000011519090                          182-010-020
# 1  000001074743  000000000011519101                          182-010-020
# 2  000001074744  000000000011519101                          182-010-020
# 3  000001074745  000000000011519104                          182-010-020
# 4  000001074746  000000000011519104                          182-010-020
# 5  000001074747  000000000011519104                          182-010-020
# 6  000001074748  000000000011519112                          182-010-020
# 7  000001074750  000000000011519112                          182-010-020
# 8  000001074751  000000000011519112                          182-010-020
# 9  000001074752  000000000011519120                          182-010-020
#
#     createdon coord_type maintplant priority bic_zequihist
# 0  2009-12-29  ZS01       4026                000001074742
# ...
