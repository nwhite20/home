# %%
# %run '00_database_connectivity_setup.ipynb'
# Out:
# C:\Anaconda2\lib\site-packages\pandas\computation\__init__.py:19: UserWarning: The installed version of numexpr 2.4.4 is not supported in pandas and will be not be used
#
#   UserWarning)

# %%
# %%showsql
# SELECT * FROM information_schema.tables
# WHERE table_schema = 'data_science'
# Out:
#    table_catalog  table_schema                       table_name  table_type  \
# 0   fmc_poc       data_science  inventory                        BASE TABLE
# 1   fmc_poc       data_science  coating_spcs                     BASE TABLE
# 2   fmc_poc       data_science  elastomer_specs                  BASE TABLE
# 3   fmc_poc       data_science  materialspecs                    BASE TABLE
# 4   fmc_poc       data_science  weld_specs                       BASE TABLE
# 5   fmc_poc       data_science  purchasingspcs                   BASE TABLE
# 6   fmc_poc       data_science  qspecs                           BASE TABLE
# 7   fmc_poc       data_science  tce_uom                          BASE TABLE
# 8   fmc_poc       data_science  tce_part_types                   BASE TABLE
# 9   fmc_poc       data_science  sap_uom                          BASE TABLE
# 10  fmc_poc       data_science  sourcepartmaster                 BASE TABLE
# ...

# %%
# %%showsql
# SELECT * FROM data_science.partbom_exploded_int limit 5
# Out:
#   plant    material  lvl   component  qty unit
# 0  EWHG  02-411-062  0    02-411-063  1.0  EA
# 1  EWHG  02-411-062  0    3232434     1.0  EA
# 2  EWHG  02-411-062  0    86-693-001  1.0  EA
# 3  EWHG  02-411-062  0    86-691-090  1.0  EA
# 4  EWHG  02-411-062  0    88-030-080  1.0  EA

# %%
# %%showsql
# SELECT COUNT(*) FROM data_science.partbom_exploded_int where plant = 'EWHG'
# Out:
#      count
# 0  2072494

# %%
# %%showsql
# SELECT COUNT(*) FROM data_science.partbom_exploded_int
# Out:
#      count
# 0  2072494

# %%
# %%showsql
# SELECT * FROM data_science.partbom_exploded_int WHERE material = '02-411-063'
# Out:
#   plant    material  lvl   component  qty unit
# 0  EWHG  02-411-063  0    70-730-851  1.0  IN

# %%
# %%showsql
# SELECT * FROM data_science.partbom_exploded_int WHERE component = '02-411-063'
# Out:
#   plant    material  lvl   component  qty unit
# 0  EWHG  02-411-062  0    02-411-063  1.0  EA

# %%
# %%showsql
# SELECT * FROM data_science.partbom_exploded_int WHERE material = '02-411-062'
# Out:
#   plant    material  lvl   component  qty unit
# 0  EWHG  02-411-062  0    02-411-063  1.0  EA
# 1  EWHG  02-411-062  0    3232434     1.0  EA
# 2  EWHG  02-411-062  0    86-693-001  1.0  EA
# 3  EWHG  02-411-062  0    86-691-090  1.0  EA
# 4  EWHG  02-411-062  0    88-030-080  1.0  EA
# 5  EWHG  02-411-062  0    48-180-016  1.0  EA
# 6  EWHG  02-411-062  1    70-730-851  1.0  IN

# %%
# %%showsql
# SELECT * FROM data_science.partbom_exploded_int WHERE component= '02-411-062'
# Out:
# Empty DataFrame
# Columns: [plant, material, lvl, component, qty, unit]
# Index: []
