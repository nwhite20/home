# %%
# %run '00_database_connectivity_setup.ipynb'

# %%
# %%showsql
# SELECT * FROM nate.full_features LIMIT 1
# Out:
#       ordr     material                             material_desc   component  \
# 0  1147762  P1000058802  ACTUATOR ASSY F/ M3000 5 1/8-10K, W/LINE  48-081-086
#
#                              component_desc     uom plant  orders_replaced  \
# 0  O-RING, .275(6.99) IN(MM) CS X 16.955(43  EA      4011  1
#
#    orders_serviced  pctreplaced  leadtimecalday  leadtimeworkday    calday  \
# 0  55               0.018182     0.0             0.0              20110901
#
#   pmplangrp pmacttype division   customer funct_loc salesorg    refdat abcinc  \
# 0  292       023       01       PLANT4025            B001     20110920
#
#    ord_intime changedon changedby actfinish  actstart bic_zactfinsh  \
# 0  0           20110920  SILVATA   00000000  20110901  00000000
#
#   bic_zreledt category bic_zawerk bic_zcrtdat  \
# 0  20110920             4025       171958
#
#                              bic_zsystatus workcenter bus_area bic_zphase  \
# ...

# %%
# %%showsql
# SELECT * FROM nate.prediction_input LIMIT 1
# Out:
#     component  orders_replaced  orders_serviced  pctreplaced  leadtimecalday  \
# 0  48-081-086  1                55               0.018182     0.0
#
#      actstart abcinc  bic_zphase matl_has_coatings matl_has_documents  \
# 0  2011-09-01         3           True              False
#
#   matl_has_matlspecs matl_has_weldspecs matl_has_qspecs has_coatings  \
# 0  False              False              False           False
#
#   has_documents has_matlspecs has_weldspecs has_qspecs  material_weight  \
# 0  False         False         False         False      1400.0
#
#   material_surface_matl material_subsea_matl  component_weight  \
# 0  True                  True                 0.1
#
#   component_surface_matl component_subsea_matl
# 0  True                   True

# %% [markdown]
# Clean it up!
